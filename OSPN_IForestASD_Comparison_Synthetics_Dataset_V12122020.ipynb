# %% [markdown]
# # Comparison of Original IForestASD, SADWIN IFA, PADWIN IFA, and NDKSWIN

# %% [markdown]
# L'objectif est de voir comment les 4 méthodes se comportent avec différents jeux de données.
# * SAWIN IFA (Scores based ADWIN on IForestASD) utilise le score des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Ce score est utilisé par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * PAWIN IFA (Prediction based ADWIN on IForestASD) utilise la classification des données sur la base du modèle créé avec IForest ASD dans les fenêtres précédentes. Cette classification est utilisée par ADWIN pour vérifier si le modèle drift pour pas. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.
# * NDKSWIN IFA (N-Dimensional KSWIN on IForestASD) utilise les données de la fenêtre courante pour détecter si elles drift sur au moins une colonne. NDKSWIN est une adaptation de KSWIN de scikit-multiflow pour les données à n dimensions. Une fois le drift détecté, le modèle est mis à jour sur la base de la fenêtre courante et l'ancien modèle est totalement supprimé.

# %% [markdown]
# ## Install skmultiflow if needed
# You need to install git

# %%
#print("scikit-multiflow package installation")
#!pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %%
try:
    import skmultiflow
except ImportError as e:
    print("scikit-multiflow package installation")
    # !pip install -U git+https://github.com/scikit-multiflow/scikit-multiflow

# %% [markdown]
# ## Importations and configurations

# %%
# %matplotlib notebook
import matplotlib as plt
plt.interactive(True)
from source import functions
func = functions.Comparison()
import datetime

# %% [markdown]
# ## General parameters for the evaluation

# %%
#************************ Execution settings *******************************
window_sizes = [100, 500]
n_estimators = [30]
execution_number = 1 # Number of execution because of the random character of IForest
anomaly_threshold = 0.5 # Anomaly threshold to decide which is anomaly or not
max_sample = 10000 # Total size of data to examine (windows number = max_sample/window)
n_wait = max_sample # The evaluation step size
# Used metric in the evaluation. Attention to use the metrics availlable in skmultiflow
metrics=['accuracy', 'f1', 'precision', 'recall', 'true_vs_predicted', 'kappa', 'kappa_m', 'running_time', 'model_size']

#************************ Stream data settings *******************************
window_save_size = 100
window_number = round((max_sample/window_save_size),0) # The number of window to save on .csv file

# Parameters for NDWSIN IFA
alpha=0.01
n_dimensions=2 # Number of dimensions to use for the test of the drift concept (normally 50% of m)
n_tested_samples=0.1 # Percentage of data to pick in the window to test the drift concept
fixed_checked_dimension = False # IF False, dimension will be choose randomly, if not on the 
fixed_checked_sample=False

# %% [markdown]
# ## Execution Function

# %%
def execute_comparision():
    file_path = func.save_stream_data_generated(stream=stream, window = window_save_size, 
                                                result_folder=test_name, window_number = window_number)
    for window in window_sizes:
        stream2 = func.get_file_stream(path=file_path)
        for n_estimator in n_estimators:
            print("")
            print("******************************** Window = "+str(window)+" and n_estimator = "+str(n_estimator)+" ********************************")
            func.run_IForestASDs_comparison2(execution_number=execution_number, stream=stream2, 
                                            stream_n_features=stream.n_features, window = window, 
                             estimators = n_estimator, anomaly = anomaly_threshold, drift_rate = drift_rate, 
                             result_folder=test_name, max_sample=max_sample, n_wait=n_wait, metrics=metrics,
                             #n_estimators_updated=n_estimators_updated, updated_randomly=updated_randomly,
                            alpha=alpha, n_dimensions=n_dimensions, n_tested_samples=n_tested_samples,
                            fixed_checked_dimension = fixed_checked_dimension, fixed_checked_sample=fixed_checked_sample)
    
    directory_path = 'results/'+str(test_name)
    func.merge_file2(folder_path=directory_path, output_file = 'output_madkour.csv',skiprows=(4 + 4))

# %% [markdown]
# ## Applied On Simple Stream Dataset
# ### Idea and waitting results
# ### Results
# #### Model updating
# #### Method performances
#
# ### Summary

# %%
dataset_name = "Generator"
test_name = dataset_name+'_'+str(datetime.datetime.now())
drift_rate = 0.1
stream = func.get_dataset(dataset_name=dataset_name, classification_function=0,noise_percentage=0.1, random_state=1)
execute_comparision()
# Out:
# Please find the data used on results/Generator_2022-09-23 17:15:32.112100/Generator_2022-09-23 17:15:32.112100_dataUsed.csv
#
# ******************************** Window = 100 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <div id='e2be2838-e565-45b9-b515-26dfa39d9be6'></div>
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#
# The model was updated by training a new iForest with the version : AnomalyRate
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #------------------- [5%] [14.89s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [33.50s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [52.38s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ####---------------- [20%] [71.07s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [89.53s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [108.09s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [126.66s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [145.27s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [163.95s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [183.24s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [202.22s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [221.09s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [240.08s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [258.75s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###############----- [75%] [277.36s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [296.33s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [314.99s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [333.57s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [352.36s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [370.94s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.4635
# O_IFA - Kappa        : -0.0371
# O_IFA - Kappa M      : -0.5217
# O_IFA - Precision: 0.3203
# O_IFA - Recall: 0.3160
# O_IFA - F1 score: 0.4126
# O_IFA - Training time (s)  : 1.85
# O_IFA - Testing time  (s)  : 92.83
# O_IFA - Total time    (s)  : 94.68
# O_IFA - Size (kB)          : 562.1621
# SADWIN_IFA - Accuracy     : 0.4500
# SADWIN_IFA - Kappa        : -0.0582
# SADWIN_IFA - Kappa M      : -0.5600
# SADWIN_IFA - Precision: 0.3128
# SADWIN_IFA - Recall: 0.3079
# SADWIN_IFA - F1 score: 0.4015
# SADWIN_IFA - Training time (s)  : 0.81
# SADWIN_IFA - Testing time  (s)  : 91.29
# SADWIN_IFA - Total time    (s)  : 92.10
# SADWIN_IFA - Size (kB)          : 605.4424
# PADWIN_IFA - Accuracy     : 0.4428
# PADWIN_IFA - Kappa        : -0.0526
# PADWIN_IFA - Kappa M      : -0.5804
# PADWIN_IFA - Precision: 0.3141
# PADWIN_IFA - Recall: 0.3097
# PADWIN_IFA - F1 score: 0.3991
# PADWIN_IFA - Training time (s)  : 0.78
# PADWIN_IFA - Testing time  (s)  : 91.00
# PADWIN_IFA - Total time    (s)  : 91.78
# PADWIN_IFA - Size (kB)          : 613.6846
# NDKSWIN_IFA - Accuracy     : 0.4413
# NDKSWIN_IFA - Kappa        : -0.0638
# NDKSWIN_IFA - Kappa M      : -0.5847
# NDKSWIN_IFA - Precision: 0.3103
# NDKSWIN_IFA - Recall: 0.3055
# NDKSWIN_IFA - F1 score: 0.3961
# NDKSWIN_IFA - Training time (s)  : 0.21
# NDKSWIN_IFA - Testing time  (s)  : 91.92
# NDKSWIN_IFA - Total time    (s)  : 92.13
# NDKSWIN_IFA - Size (kB)          : 583.2930
#
# Please find the result on results/Generator_2022-09-23 17:15:32.112100/result_Number0_for_WS100_NE30updated_count.csv
#
# Please find evaluation results here results/Generator_2022-09-23 17:15:32.112100/result_Number0_for_WS100_NE30.csv
#
# ******************************** Window = 500 and n_estimator = 30 ********************************
# *************************************** Execution N° 0**********************************
# <div id='818c1560-f889-49c7-a95c-9e7d5fa17327'></div>
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 1 sample(s).
# Evaluating...
#  #------------------- [5%] [0.01s]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/skmultiflow/visualization/evaluation_visualizer.py:340: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   self.fig.tight_layout(rect=[0, .04, 1, 0.98], pad=2.6, w_pad=0.4, h_pad=1.0)
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##------------------ [10%] [123.10s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###----------------- [15%] [242.31s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ####---------------- [20%] [363.04s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #####--------------- [25%] [483.26s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ######-------------- [30%] [601.83s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #######------------- [35%] [722.16s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ########------------ [40%] [842.16s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #########----------- [45%] [961.04s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##########---------- [50%] [1082.34s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###########--------- [55%] [1202.70s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ############-------- [60%] [1323.81s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #############------- [65%] [1444.63s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##############------ [70%] [1566.40s]
# The model was updated by training a new iForest with the version : AnomalyRate
#
# The model was updated by training a new iForest with the version : NDKSWIN
#  ###############----- [75%] [1688.26s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ################---- [80%] [1810.56s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################--- [85%] [1929.87s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ##################-- [90%] [2050.04s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  ###################- [95%] [2170.09s]
# The model was updated by training a new iForest with the version : AnomalyRate
#  #################### [100%] [2292.34s]
# Processed samples: 10000
# Mean performance:
# O_IFA - Accuracy     : 0.4070
# O_IFA - Kappa        : -0.0255
# O_IFA - Kappa M      : -0.6820
# O_IFA - Precision: 0.3208
# O_IFA - Recall: 0.3062
# O_IFA - F1 score: 0.3821
# O_IFA - Training time (s)  : 1.78
# O_IFA - Testing time  (s)  : 579.17
# O_IFA - Total time    (s)  : 580.95
# O_IFA - Size (kB)          : 1881.0605
# SADWIN_IFA - Accuracy     : 0.3962
# SADWIN_IFA - Kappa        : -0.0177
# SADWIN_IFA - Kappa M      : -0.7126
# SADWIN_IFA - Precision: 0.3230
# SADWIN_IFA - Recall: 0.3093
# SADWIN_IFA - F1 score: 0.3728
# SADWIN_IFA - Training time (s)  : 0.94
# SADWIN_IFA - Testing time  (s)  : 571.27
# SADWIN_IFA - Total time    (s)  : 572.21
# SADWIN_IFA - Size (kB)          : 1829.5244
# PADWIN_IFA - Accuracy     : 0.4194
# PADWIN_IFA - Kappa        : 0.0071
# PADWIN_IFA - Kappa M      : -0.6468
# PADWIN_IFA - Precision: 0.3364
# PADWIN_IFA - Recall: 0.3200
# PADWIN_IFA - F1 score: 0.3946
# PADWIN_IFA - Training time (s)  : 0.93
# PADWIN_IFA - Testing time  (s)  : 567.88
# PADWIN_IFA - Total time    (s)  : 568.80
# PADWIN_IFA - Size (kB)          : 1972.3291
# NDKSWIN_IFA - Accuracy     : 0.4027
# NDKSWIN_IFA - Kappa        : -0.0260
# NDKSWIN_IFA - Kappa M      : -0.6942
# NDKSWIN_IFA - Precision: 0.3201
# NDKSWIN_IFA - Recall: 0.3059
# NDKSWIN_IFA - F1 score: 0.3785
# NDKSWIN_IFA - Training time (s)  : 0.21
# NDKSWIN_IFA - Testing time  (s)  : 569.77
# NDKSWIN_IFA - Total time    (s)  : 569.98
# NDKSWIN_IFA - Size (kB)          : 1953.5000
#
# Please find the result on results/Generator_2022-09-23 17:15:32.112100/result_Number0_for_WS500_NE30updated_count.csv
#
# Please find evaluation results here results/Generator_2022-09-23 17:15:32.112100/result_Number0_for_WS500_NE30.csv
# Please find the merged result file on results/Generator_2022-09-23 17:15:32.112100/output_madkour.csv_full.csv
# /Users/ahmedmadkour/Documents/PhD/IForestASD_based_methods_in_scikit_Multiflow/source/functions.py:708: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(folder_path + "/" + file_, sep=',', skiprows=skiprows, header=0,
# /Users/ahmedmadkour/Documents/PhD/IForestASD_based_methods_in_scikit_Multiflow/source/functions.py:691: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(folder_path + "/" + file_, sep=',', skiprows=1, header=0, dtype='unicode',
# /Users/ahmedmadkour/Documents/PhD/IForestASD_based_methods_in_scikit_Multiflow/source/functions.py:691: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(folder_path + "/" + file_, sep=',', skiprows=1, header=0, dtype='unicode',
# /Users/ahmedmadkour/Documents/PhD/IForestASD_based_methods_in_scikit_Multiflow/source/functions.py:708: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(folder_path + "/" + file_, sep=',', skiprows=skiprows, header=0,
